# %%
import paho.mqtt.client as mqtt
import redis
from time import time

# %%
# get current topic
myTopic = "topic/ML4IOT_Project_Polito"

# Subscriber
"""
here connect to redis, create timeseries
"""

REDIS_HOST = 'redis-15285.c55.eu-central-1-1.ec2.cloud.redislabs.com'
REDIS_PORT = 15285
REDIS_USERNAME = 'default'
REDIS_PASSWORD = 'jIhc6ILZOleRAZ3hOcSIylnJr8ZyBtRT'
timeseries_name = "AudioIOT"

redis_client = redis.Redis(
    host=REDIS_HOST, 
    port=REDIS_PORT, 
    username=REDIS_USERNAME, 
    password=REDIS_PASSWORD)
is_connected = redis_client.ping()

#redis_client.flushdb()

def on_connect(client, userdata, flags, rc):
#   print("Connected with result code "+str(rc))
  client.subscribe(myTopic)

def on_message(client, userdata, msg):
    print(msg.topic ,  msg.payload.decode())
    """
    send to redis
    name of ts is AudioIOT
    """
    ts_name = f"{msg.payload.decode().split('_')[0]}_{timeseries_name}"
    label   = f"{msg.payload.decode().split('_')[1]}"
    print(ts_name,label)
    
    timestamp =str(int(time())*1000)
    try:
        redis_client.ts().create(ts_name, chunk_size=128)
        print("TS created!")
    except redis.ResponseError:
        #print("Cannot create this ts")
        pass
    try:
        redis_client.ts().add(ts_name,timestamp,label)
    except redis.exceptions.ResponseError as e:
        print("Cannot add this value!")
        pass

# %%
keys = redis_client.keys('*')
print(keys)
# Out:
# [b'0x86ac561e351_AudioIOT']

# %%
client = mqtt.Client()
client.connect("test.mosquitto.org",1883,60)

client.on_connect = on_connect
client.on_message = on_message

client.loop_forever()
# Out:
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_2
# 0x86ac561e351_AudioIOT 2
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_1
# 0x86ac561e351_AudioIOT 1
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_2
# 0x86ac561e351_AudioIOT 2
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_2
# 0x86ac561e351_AudioIOT 2
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_1
# 0x86ac561e351_AudioIOT 1
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_1
# 0x86ac561e351_AudioIOT 1
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_4
# 0x86ac561e351_AudioIOT 4
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_1
# 0x86ac561e351_AudioIOT 1
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_4
# 0x86ac561e351_AudioIOT 4
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_4
# 0x86ac561e351_AudioIOT 4
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_6
# 0x86ac561e351_AudioIOT 6
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_4
# 0x86ac561e351_AudioIOT 4
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_0
# 0x86ac561e351_AudioIOT 0
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_1
# 0x86ac561e351_AudioIOT 1
# topic/ML4IOT_Project_Polito 0x86ac561e351_3
# 0x86ac561e351_AudioIOT 3
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_5
# 0x86ac561e351_AudioIOT 5
# topic/ML4IOT_Project_Polito 0x86ac561e351_7
# 0x86ac561e351_AudioIOT 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [16], line 7
#       4 client.on_connect = on_connect
#       5 client.on_message = on_message
# ----> 7 client.loop_forever()
#
# File ~/.local/lib/python3.10/site-packages/paho/mqtt/client.py:1756, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754 rc = MQTT_ERR_SUCCESS
#    1755 while rc == MQTT_ERR_SUCCESS:
# -> 1756     rc = self._loop(timeout)
#    1757     # We don't need to worry about locking here, because we've
#    1758     # either called loop_forever() when in single threaded mode, or
#    1759     # in multi threaded mode when loop_stop() has been called and
#    1760     # so no other threads can access _out_packet or _messages.
#    1761     if (self._thread_terminate is True
#    1762         and len(self._out_packet) == 0
#    1763             and len(self._out_messages) == 0):
#
# File ~/.local/lib/python3.10/site-packages/paho/mqtt/client.py:1150, in Client._loop(self, timeout)
#    1147     rlist = [self._sock, self._sockpairR]
#    1149 try:
# -> 1150     socklist = select.select(rlist, wlist, [], timeout)
#    1151 except TypeError:
#    1152     # Socket isn't correct type, in likelihood connection is lost
#    1153     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:

# %%
redis_client.flushdb()
print(time())
# Out:
# 1684142199.5892408

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=89af4758-9cff-4ec5-8049-9b03b4da8660' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
